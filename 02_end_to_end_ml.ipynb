# %%
mkdir -p ~/.kaggle && echo KGAT_b88f04790db21b5b700dcc262c030031 > ~/.kaggle/access_token && chmod 600 ~/.kaggle/access_token

# %%
# !kaggle competitions download -c house-prices-advanced-regression-techniques
# Out:
# ...
# 100% 199k/199k [00:00<00:00, 20.5MB/s]
