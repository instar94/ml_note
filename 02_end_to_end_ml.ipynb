# %%
# 캐글에서 데이터 가져오기mkdir -p ~/.kaggle && echo KGAT_b88f04790db21b5b700dcc262c030031 > ~/.kaggle/access_token && chmod 600 ~/.kaggle/access_token

# %%
# !unzip -q house-prices-advanced-regression-techniques.zip
# !ls  # train.csv, test.csv 확인
# Out:
# data_description.txt				 sample_submission.csv
# house-prices-advanced-regression-techniques.zip  test.csv
# sample_data					 train.csv

# %%
# 데이터 확인

# %%
import pandas as pd
train_df = pd.read_csv('train.csv')
print(train_df.shape)
# Out:
# (1460, 81)
